# %% [markdown]
# # Phonetics in R

# %% [markdown]
# ---

# %%
.libPaths()
# Out:
# [1] "/Library/Frameworks/R.framework/Versions/4.0/Resources/library"

# %%
packages <- c(
    'ggplot2',
    'readr',
    'dplyr',
    'tidyverse',
    'scales',
    'repr',
    'phonR',
    'vowels',
    'magrittr'
)

# Install packages not yet installed
installed_packages <- packages %in% rownames(installed.packages())
if (any(installed_packages == FALSE)) {
    install.packages(packages[!installed_packages])
}

# Load packages
invisible(lapply(packages, library, character.only = TRUE))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.1.2     ✔ stringr 1.4.0
# ✔ tidyr   1.1.3     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# Attaching package: ‘magrittr’
#
#
# The following object is masked from ‘package:purrr’:
#
#     set_names
#
#
# The following object is masked from ‘package:tidyr’:
#
#     extract

# %% [markdown]
# ---

# %%
data<-read.csv('student_vowels_avg.csv')
data

#read.csv('korean_vowels_example.csv')
#read.delim('korean_vowels_example.csv', sep=',', encoding='UTF-8')
# Out:
#   Vowel Unicode F1_Hz   F2_Hz
# 1 æ     00E6    980.860 1727.465
# 2 ɛ     025B    790.555 1973.815
# 3 i     0069    338.215 2858.355
# 4 ɪ     026A    584.505 2205.925
# 5 a     0061    823.100 1115.180
# 6 ɔ     0254    788.665 1080.670
# 7 ʊ     028A    638.250 1389.895
# 8 ʌ     028C    721.300 1446.240
# 9 u     0075    558.950 1471.395

# %%
options(repr.plot.width=10, repr.plot.height=4)

plt <- ggplot(data, aes(x=F2_Hz, y=F1_Hz, label=Vowel, color=Vowel))+
geom_text()+
scale_x_reverse()+
scale_y_reverse()+
theme(legend.position='none')

suppressWarnings(print(plt))
# https://stackoverflow.com/questions/13286531/how-to-suppress-warnings-when-plotting-with-ggplot
# Out:
# plot without title

# %% [markdown]
# ---

# %%
#https://guilhermegarcia.github.io/vowels.html
set.seed(10)

# %%
vowels = data.frame(
    vowel = rep(c('a', 'e', 'i', 'o', 'u'), each=50),
    F1 = c(rnorm(50, mean=800, sd=100),
           rnorm(50, mean=600, sd=100),
           rnorm(50, mean=350, sd=100),
           rnorm(50, mean=600, sd=100),
           rnorm(50, mean=350, sd=100)),
    F2 = c(rnorm(50, mean=1500, sd=150),
           rnorm(50, mean=2000, sd=150),
           rnorm(50, mean=2500, sd=150),
           rnorm(50, mean=1000, sd=150),
           rnorm(50, mean=800, sd=150))
)
vowels
# Out:
#     vowel F1       F2
# 1   a     801.8746 1661.684
# 2   a     781.5747 1639.767
# 3   a     662.8669 1280.881
# 4   a     740.0832 1364.089
# 5   a     829.4545 1397.948
# 6   a     838.9794 1659.475
# 7   a     679.1924 1396.138
# 8   a     763.6324 1329.956
# 9   a     637.3327 1335.808
# 10  a     774.3522 1348.064
# 11  a     910.1780 1561.542
# 12  a     875.5782 1571.661
# 13  a     776.1766 1150.518
# 14  a     898.7445 1502.438
# 15  a     874.1390 1647.053
# 16  a     808.9347 1620.952
# 17  a     704.5056 1517.940
# 18  a     780.4850 1134.508
# 19  a     892.5521 1504.653
# 20  a     848.2979 1449.638
# 21  a     740.3689 1460.434
# 22  a     581.4713 1446.622
# 23  a     732.5134 1427.827
# 24  a     588.0939 1533.410
# 25  a     673.4802 1864.487
# 26  a     762.6338 1724.445
# 27  a     731.2445 1392.419
# 28  a     712.7841 1429.942
# 29  a     789.8239 1599.439
# 30  a     774.6219 1845.027
# ⋮   ⋮     ⋮        ⋮
# 221 u     317.0775 719.0060
# 222 u     321.7178 511.1535
# 223 u     393.2429 951.1747
# 224 u     319.2393 758.1148
# 225 u     344.3364 612.5651
# 226 u     423.3515 987.2737
# 227 u     359.7312 771.1680
# 228 u     513.0892 936.7964
# 229 u     406.0611 476.2595
# 230 u     482.9565 993.4416
# 231 u     322.1177 735.7835
# 232 u     223.3268 761.7496
# 233 u     325.0852 999.0737
# 234 u     351.7988 925.8035
# 235 u     387.7073 580.2499
# 236 u     429.6009 707.5621
# 237 u     265.9323 815.9159
# 238 u     129.4528 523.3975
# 239 u     237.1944 557.5366
# 240 u     215.8690 834.1515
# 241 u     510.5114 938.1825
# 242 u     424.4424 750.3195
# 243 u     436.2082 993.0851
# 244 u     389.5156 808.5891
# 245 u     400.9119 469.4100
# 246 u     337.7450 721.5634
# 247 u     359.2585 962.1178
# 248 u     314.2120 763.5288
# 249 u     314.0345 663.5830
# 250 u     452.8571 669.7551

# %%
options(repr.plot.width=10, repr.plot.height=4)

plt <- ggplot(data=vowels, aes(x=F2, y=F1, color=vowel, label=vowel))+
geom_text(size=4)+ # font size
#scale_x_reverse(
#    position='top',
#    labels=unit_format(unit='Hz', sep=''),
#    breaks=seq(200, 3000, 500))+
#scale_y_reverse(
#    position='right',
#    labels=unit_format(unit='Hz', sep=''),
#    breaks=seq(100, 1000, 250))+
#labs(
#    x='F2\n',
#    y='F1\n',
#    title='Density Plot')+
#geom_density_2d(alpha=0.3)+
coord_cartesian(
    xlim=c(3000, 200),
    ylim=c(1000, 100))+
theme_classic()+
theme(
    legend.position='none',
    plot.title=element_text(hjust=0.5), # center plot title
    text=element_text(size=13))         # plot font size

plt
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=4)

plt <- ggplot(data=vowels, aes(x=F2, y=F1, color=vowel, label=vowel))+
geom_text(size=6)+ # font size
scale_x_reverse(
    position='top',
    labels=unit_format(unit='Hz', sep=''),
    breaks=seq(200, 3000, 500))+
scale_y_reverse(
    position='right',
    labels=unit_format(unit='Hz', sep=''),
    breaks=seq(100, 1000, 250))+
labs(
    x='F2\n',
    y='F1\n',
    title='Density Plot')+
geom_density_2d(alpha=0.3)+
coord_cartesian(
    xlim=c(3000, 200),
    ylim=c(1000, 100))+
theme_light()+
theme(
    legend.position='none',
    plot.title=element_text(hjust=0.5), # center plot title
    text=element_text(size=13))         # plot font size

plt
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=4)

plt <- ggplot(data=vowels, aes(x=F2, y=F1, color=vowel, label=vowel))+
geom_text(size=6)+ # font size
scale_x_reverse(
    position='top',
    labels=unit_format(unit='Hz', sep=''),
    breaks=seq(200, 3000, 500))+
scale_y_reverse(
    position='right',
    labels=unit_format(unit='Hz', sep=''),
    breaks=seq(100, 1000, 250))+
labs(
    x='F2\n',
    y='F1\n',
    title='Density Plot')+
stat_ellipse(type='norm', alpha=0.3)+
coord_cartesian(
    xlim=c(3000, 200),
    ylim=c(1000, 100))+
theme_classic()+
theme(
    legend.position='none',
    plot.title=element_text(hjust=0.5), # center plot title
    text=element_text(size=13))         # plot font size

plt
# Out:
# plot without title

# %%
means <- vowels %>% group_by(vowel) %>% summarize(meanF1=mean(F1),
                                                  meanF2=mean(F2),
                                                  seF1=sd(F1)/sqrt(n()),
                                                  seF2=sd(F2)/sqrt(n()))
means
# Out:
#   vowel meanF1   meanF2    seF1     seF2
# 1 a     765.8705 1506.9400 12.25285 21.84624
# 2 e     606.8198 2042.9371 13.81097 20.84642
# 3 i     352.4042 2516.7145 13.74746 23.33361
# 4 o     578.6033 1008.8288 13.60189 23.78942
# 5 u     351.1237  776.0376 13.04699 24.21912

# %%
options(repr.plot.width=10, repr.plot.height=4)

plt <- ggplot(data=means, aes(x=meanF2, y=meanF1, label=vowel))+
geom_errorbar(aes(ymin=meanF1-seF1, ymax=meanF1+seF1), width=0)+
geom_errorbarh(aes(xmin=meanF2-seF2, xmax=meanF2+seF2), height=0)+
geom_text(position=position_nudge(x=50, y=50), size=5)+
scale_x_reverse(position='top', labels=unit_format(unit='Hz', sep=''))+
scale_y_reverse(position='right', labels=unit_format(unit='Hz', sep=''))+
labs(x='F2\n', y='F1\n')+
theme_light()

plt
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=4)

plt <- ggplot(data=means, aes(x=meanF2, y=meanF1, color=vowel, label=vowel))+
geom_label(size=6)+ # font size
scale_x_reverse(
    position='top',
    labels=unit_format(unit='Hz', sep=''),
    breaks=seq(200, 3000, 500))+
scale_y_reverse(
    position='right',
    labels=unit_format(unit='Hz', sep=''),
    breaks=seq(100, 1000, 250))+
labs(
    x='F2\n',
    y='F1\n',
    title='Density Plot')+
stat_ellipse(data=vowels, aes(x=F2, y=F1), type='norm')+
coord_cartesian(
    xlim=c(3000, 200),
    ylim=c(1000, 100))+
theme_classic()+
theme(
    legend.position='none',
    plot.title=element_text(hjust=0.5), # center plot title
    text=element_text(size=13))         # plot font size

plt
# Out:
# plot without title

# %% [markdown]
# ---

# %%
words.f <- c(17667, 15347, 14401, 5037, 20845, 11211, 6008, 17140, 13284, 10930)
words.m <- c(5599, 19776, 13961, 10144, 6107, 16776, 31955, 21140, 5482, 2152)
words <- c(words.f, words.m)
age <- c(24, 31, 28, 21, 29, 29, 25, 32, 30, 31, 33, 26, 22, 24, 23, 23, 20, 21, 29, 27)

# %%
mean(words)
median(words)
min(words)
max(words)
sd(words)
mad(words)
# Out:
# [1] 13248.1
# [1] 13622.5
# [1] 2152
# [1] 31955
# [1] 7246.996
# [1] 7559.777

# %%
summary(words)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2152    6082   13622   13248   17272   31955

# %%
stem(words)
# Out:
#   The decimal point is 4 digit(s) to the right of the |
#
#   0 | 255666
#   1 | 0113445778
#   2 | 011
#   3 | 2

# %%
hist(words)
# Out:
# Plot with title “Histogram of words”

# %%
boxplot(words)
# Out:
# plot without title

# %%
boxplot(words.f, words.m)
# Out:
# plot without title

# %%
cor(words, age)
cor(words.f, words.m)
# Out:
# [1] -0.2604937
# [1] -0.3212523

# %%
plot(age, words)
# Out:
# plot without title

# %% [markdown]
# ---
